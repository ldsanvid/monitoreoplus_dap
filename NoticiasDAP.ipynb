# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta, timezone
from urllib.parse import urlparse
from dateutil import parser
import unicodedata
import numpy as np
import os

# === CONFIGURACIÓN GENERAL ===

# 1) Términos ligados a intereses de clientes DAP
terminos_busqueda = [
    "industria alimentaria",
    "cemento",
    "gas",
    "impuesto", 
    "iva",
    "casinos",
    "movilidad",
    "seguridad",
]

# 2) Búsqueda general para agenda nacional
termino_agenda_nacional = ["Sheinbaum","aranceles","trump"]

# Modo de fecha
modo = "rango"  # Opciones: "exacto" o "rango"
debug = True    # True para imprimir detalles por noticia
dias_rango = 2  # Solo si modo == "rango"
fecha_objetivo = datetime(2025, 11, 2).date()  # Solo si modo == "exacto"

# Lista de medios (de momento vacía: tú la llenas con tus sitios)
medios = ["eleconomista.com.mx","imagenradio.com.mx","elfinanciero.com.mx","forbes.com.mx","merca20.com",
    "eluniversal.com.mx","heraldodemexico.com.mx/nacional","nexos.com.mx","thelogisticsworld.com","t21.com.mx",
    "articulo19.org","animalpolitico.com","sinembargo.mx","codigomagenta.com.mx","latinus.us","expansion.mx",
    "nmas.com.mx/nacional","radioformula.com.mx","wradio.com.mx","unotv.com","tvazteca.com/aztecanoticias","infobae.com/mexico",
    "la-lista.com/mexico","oem.com.mx/la-prensa","oem.com.mx/elsoldemexico","proceso.com.mx","vertigopolitico.com","sdpnoticias.com",
    "lasillarota.com/nacion","excelsior.com.mx","letraslibres.com","elpais.com/mexico/","mvsnoticias.com","latimes.com","jornada.com.mx",
    "cnnespanol.cnn.com/","nytimes.com","mexico.quadratin.com.mx","milenio.com","informador.mx","washingtonpost.com",
    "realestatemarket.com.mx/mercado-inmobiliario-home/industrial","alfamexico.com/category/noticias-inmobiliarias/",
    "inmobiliare.com/","jll.com.mx/es/newsroom","eleconomista.com.mx/tags/sector-inmobiliario","milenio.com/temas/sector-inmobiliario",
    "somosindustria.com/", "mexicoindustry.com/","thelogisticsworld.com/","bloomberglinea.com/latinoamerica/mexico/"
]

headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/109.0.0.0 Safari/537.36"
    )
}

# === FUNCIONES AUXILIARES ===

def normalizar(texto):
    if not isinstance(texto, str):
        return ""
    texto = texto.lower().strip()
    texto = unicodedata.normalize("NFKD", texto)
    texto = "".join([c for c in texto if not unicodedata.combining(c)])
    return texto

def parsear_fecha_pub(pub_date_str):
    """
    Intenta parsear la fecha del feed RSS de Google News.
    Devuelve objeto datetime con timezone.
    """
    try:
        dt = parser.parse(pub_date_str)
        if dt.tzinfo is None:
            dt = dt.replace(tzinfo=timezone.utc)
        return dt
    except Exception:
        return None

# === SCRAPING DE NOTICIAS POR TÉRMINO Y MEDIO ===

noticias = []
ahora = datetime.now(timezone.utc)

for termino in terminos_busqueda:
    print(f"\n🔍 Buscando: {termino}")

    for medio in medios:
        dominio = urlparse("https://" + medio).netloc
        # Configuración para México
        url = (
            f"https://news.google.com/rss/search?"
            f"q={termino}+site:{dominio}"
            f"&hl=es-419&gl=MX&ceid=MX:es"
        )

        response = requests.get(url, headers=headers)
        if response.status_code != 200:
            print(f"⚠️ Error al obtener noticias de {dominio}")
            continue

        soup = BeautifulSoup(response.content, "xml")
        items = soup.find_all("item")

        for item in items:
            title = item.title.text if item.title else ""
            link = item.link.text if item.link else ""
            pub_date_str = item.pubDate.text if item.pubDate else ""

            pub_date = parsear_fecha_pub(pub_date_str)
            if pub_date is None:
                continue

            # Filtrado por fecha
            if modo == "exacto":
                if pub_date.date() != fecha_objetivo:
                    continue
            elif modo == "rango":
                if ahora - pub_date > timedelta(days=dias_rango):
                    continue

                source = item.source.text if item.source else ""
                description = item.description.text if item.description else ""
                contenido = f"{title} {description}".lower()
                if termino.lower() in contenido:
                    if debug:
                        print(f"📰 {title} | {pub_date.date()} | {source}")
                    noticias.append([
                        pub_date.astimezone(timezone.utc),
                        title,
                        link,
                        termino,
                        source,  # aquí guardamos el medio
                    ])


# === BLOQUE EXTRA: TITULARES GENERALES PARA "AGENDA NACIONAL" ===

from urllib.parse import quote_plus  # ya lo tienes arriba, pero no pasa nada si está repetido

print("\n🔍 Buscando titulares generales de México (agenda_nacional)")

# Construimos una query OR con las palabras de agenda nacional
# Ejemplo: "Sheinbaum OR aranceles OR trump"
query_agenda = " OR ".join(termino_agenda_nacional)
query_agenda_encoded = quote_plus(query_agenda)

url_agenda = (
    "https://news.google.com/rss/search?"
    f"q={query_agenda_encoded}"
    "&hl=es-419&gl=MX&ceid=MX:es"
)

response = requests.get(url_agenda, headers=headers)
if response.status_code == 200:
    soup = BeautifulSoup(response.content, "xml")
    items = soup.find_all("item")

    # Tomamos solo 4–5 ítems (ajustable)
    max_agenda = 15
    count = 0

    for item in items:
        if count >= max_agenda:
            break

        title = item.title.text if item.title else ""
        link = item.link.text if item.link else ""
        pub_date_str = item.pubDate.text if item.pubDate else ""
        pub_date = parsear_fecha_pub(pub_date_str)
        if pub_date is None:
            continue

        # Mismo filtro de fecha que en el resto del scraper
        if modo == "exacto":
            if pub_date.date() != fecha_objetivo:
                continue
        elif modo == "rango":
            if ahora - pub_date > timedelta(days=dias_rango):
                continue

        if debug:
            print(f"📰 [AGENDA] {title} | {pub_date.date()}")

        # El campo 'medio' lo dejamos vacío; luego se llenará con el split " - "
        noticias.append([
            pub_date.astimezone(timezone.utc),
            title,
            link,
            "agenda_nacional",
            ""
        ])
        count += 1
else:
    print("⚠️ No se pudieron obtener titulares generales de México")


# === GUARDAR RESULTADOS EN CSV NOTICIAS_DAP ===

carpeta_salida = "."  # raíz del proyecto; cambia si quieres "noticias"
os.makedirs(carpeta_salida, exist_ok=True)

if noticias:
    df = pd.DataFrame(
        noticias,
        columns=["fecha_dt", "titular_raw", "enlace", "termino", "medio"]
    )
    # Separar "titulo - Medio"
    partes = df["titular_raw"].str.split(" - ", n=1, expand=True)
    
    # Título limpio (antes del " - ")
    df["titular"] = partes[0]
    
    # Medio de comunicación (después del " - ")
    df["medio"] = partes[1].fillna("")

    # Convertir a fecha (sin hora) y a string YYYY-MM-DD
    df["fecha_dt"] = pd.to_datetime(df["fecha_dt"], errors="coerce")
    df = df[df["fecha_dt"].notna()]
    df["fecha"] = df["fecha_dt"].dt.strftime("%Y-%m-%d")
    # Nos quedamos solo con las columnas que quieres
    df_final = df[["fecha", "titular", "termino", "enlace", "medio"]].drop_duplicates()

    # Nombre del archivo
    sufijo_fecha = (
        fecha_objetivo.strftime("%Y-%m-%d")
        if modo == "exacto"
        else ahora.strftime("%Y-%m-%d")
    )
    nombre_archivo = os.path.join(
        carpeta_salida,
        f"noticias_dap_{sufijo_fecha}.csv"
    )

    df_final.to_csv(nombre_archivo, index=False, encoding="utf-8-sig")
    print(f"\n✅ Archivo guardado como '{nombre_archivo}' con {len(df_final)} noticias")
else:
    print("\n❌ No se encontraron noticias que cumplan los filtros.")
# Out:
# 🔍 Buscando: industria alimentaria
# 📰 ¿Cómo cambiarán los medicamentos para perder peso a la industria alimentaria? Aquí te contamos - Forbes México | 2026-02-01 | Forbes México
#
# 🔍 Buscando: cemento
#
# 🔍 Buscando: gas
# 📰 Cuba se queda sin gas LP: Jamaica se ‘rehúsa’ a venderle petróleo por ‘terror’ a aranceles de Trump - El Financiero | 2026-02-02 | El Financiero
# 📰 Venezuela exporta por primera vez gas licuado de petróleo, PDVSA marca un hito energético - El Universal | 2026-02-02 | El Universal
# 📰 Tres fugas de gas en cinco meses en Coacalco - El Universal | 2026-02-01 | El Universal
# 📰 Gas Natural y TMEC - El Heraldo de México | 2026-02-02 | El Heraldo de México
# 📰 Explota una casa en la colonia Axotla en Álvaro Obregón por acumulación de gas - El Heraldo de México | 2026-02-02 | El Heraldo de México
# 📰 Graban momento exacto en que ocurre explosión por acumulación de gas en colonia Axotla | VIDEO FUERTE - El Heraldo de México | 2026-02-03 | El Heraldo de México
# 📰 ¿Dónde cargar gasolina más barata HOY? Precios de este lunes 2 de febrero 2026 - El Heraldo de México | 2026-02-02 | El Heraldo de México
# 📰 Las tortugas han reconstruido las Galápagos: las grandes ingenieras ambientales - Animal Politico | 2026-02-02 | Animal Politico
# 📰 Zarpa el primer buque de gas licuado de petróleo de Venezuela - LatinUS | 2026-02-02 | LatinUS
# 📰 Se registra desabasto de gas LP en Centla tras operativo contra distribuidora por irregularidades - LatinUS | 2026-02-01 | LatinUS
# 📰 El gas natural, la crisis por venir a México en 2028 - expansion.mx | 2026-02-03 | expansion.mx
# 📰 Explosión de Tanque de Gas durante Feria Patronal en Puebla Provoca Fuerte Incendio - N+ | 2026-02-02 | N+
# 📰 Venezuela Exportó su Primer Cargamento de Gas Licuado de Petróleo, Anunció Delcy Rodríguez - N+ | 2026-02-02 | N+
# 📰 Video: Momento Exacto de la Explosión de una Casa por Acumulación de Gas en Álvaro Obregón - N+ | 2026-02-02 | N+
# 📰 Desalojan Edificios por Choque que Provocó Fuga de Gas y Agua en Monterrey - N+ | 2026-02-02 | N+
# 📰 Explota Tanque de Gas durante Feria Patronal en Puebla - N+ | 2026-02-02 | N+
# 📰 Fuga de Gas en Vivienda de la Col. Doctores, CDMX, deja un Muerto - N+ | 2026-02-02 | N+
# 📰 Adulta Mayor Narra Cómo Chocó contra Tuberías que Provocó Fuga de Gas y Agua en Monterrey - N+ | 2026-02-03 | N+
# 📰 Mando Unificado Oriente duplica fuerza de seguridad en Valle de Chalco - estadodemexico.heraldodemexico.com.mx | 2026-02-02 | estadodemexico.heraldodemexico.com.mx
# 📰 Panorama global de ciberseguridad 2026 - El Heraldo de México | 2026-02-02 | El Heraldo de México
# 📰 Crece la percepción de inseguridad - El Heraldo de México | 2026-02-03 | El Heraldo de México
# 📰 Extorsión, trata de personas y crimen organizado: los retos de seguridad en las sedes del Mundial en México - Expansión Política | 2026-02-03 | Expansión Política
# 📰 Detienen a Tres Personas por Robo a Tienda en Monterrey; Participó Guardia de Seguridad - N+ | 2026-02-02 | N+
# 📰 Así se Encuentra Pueblo Quieto Tras Operativo de Seguridad - N+ | 2026-02-03 | N+
# 📰 Seguridad en Guanajuato: enero de 2026 registra la cifra más baja de homicidios dolosos en 8 años - Radio Fórmula | 2026-02-02 | Radio Fórmula
# 📰 Muere el obispo de BCS, Miguel Ángel Alba Díaz, una voz crítica en la seguridad y con las desapariciones - Radio Fórmula | 2026-02-02 | Radio Fórmula
# 📰 Últimas noticias de Seguridad y justicia - Radio Fórmula | 2026-02-02 | Radio Fórmula
# 📰 En 2026 cambian las monedas de 10 pesos: nuevos metales y mayor seguridad - UnoTV | 2026-02-02 | UnoTV
# 📰 Qué hacer en la noche para cuidar la seguridad del celular: apagarlo o dejarlo bloqueado - Infobae | 2026-02-01 | Infobae
# 📰 El presidente Bukele anuncia próxima visita a Chile para cooperación en seguridad - Infobae | 2026-02-01 | Infobae
# 📰 La Policía Nacional Civil de Guatemala refuerza seguridad en centros educativos con el inicio del ciclo escolar - Infobae | 2026-02-02 | Infobae
# 📰 Bajo fuerte esquema de seguridad, fue extraditado a Estados Unidos ‘Pipe Tuluá’, líder de uno de los grupos de narcos más fuertes de Colombia - Infobae | 2026-02-03 | Infobae
# 📰 Mal enero para los trabajadores: la Seguridad Social pierde 270.782 afiliados y el paro suma 30.392 desempleados - Infobae | 2026-02-03 | Infobae
# 📰 Australia refuerza las medidas de seguridad ante la visita del presidente de Israel - Infobae | 2026-02-03 | Infobae
# 📰 Seguridad en Irapuato: Balean a hombre motociclista en el Centro Histórico - El Sol de México | 2026-02-03 | El Sol de México
# 📰 ¿Policías solo con secundaria? Diputada alerta riesgos y pide mayor preparación para quienes cuidan tu seguridad en Aguascalientes - El Sol de México | 2026-02-03 | El Sol de México
# 📰 Fiscalía unifica a las fuerzas de seguridad - El Sol de México | 2026-02-03 | El Sol de México
# 📰 Tras denuncias ciudadanas, refuerzan recorridos de seguridad en Pantelhó - El Sol de México | 2026-02-03 | El Sol de México
# 📰 Fortalecer seguridad en campos de fútbol llanero debe discutirse entre autoridades y líderes de ligas - El Sol de México | 2026-02-03 | El Sol de México
# 📰 Penales de Veracruz tienen sobrepoblación del 25%, Secretaría de Seguridad realizará Registro Nacional - El Sol de México | 2026-02-03 | El Sol de México
# 📰 El patrón virtual y el futuro de la seguridad social en México - El Sol de México | 2026-02-02 | El Sol de México
# 📰 Locatarios de Tulancingo exigen más seguridad ante robos - El Sol de México | 2026-02-03 | El Sol de México
# 📰 Seguridad en Irapuato: Balean a hombre motociclista en el Centro Histórico - El Sol de México | 2026-02-03 | El Sol de México
# 📰 ¿Policías solo con secundaria? Diputada alerta riesgos y pide mayor preparación para quienes cuidan tu seguridad en Aguascalientes - El Sol de México | 2026-02-03 | El Sol de México
# 📰 Fiscalía unifica a las fuerzas de seguridad - El Sol de México | 2026-02-03 | El Sol de México
# 📰 Tras denuncias ciudadanas, refuerzan recorridos de seguridad en Pantelhó - El Sol de México | 2026-02-03 | El Sol de México
# 📰 Fortalecer seguridad en campos de fútbol llanero debe discutirse entre autoridades y líderes de ligas - El Sol de México | 2026-02-03 | El Sol de México
# 📰 Penales de Veracruz tienen sobrepoblación del 25%, Secretaría de Seguridad realizará Registro Nacional - El Sol de México | 2026-02-03 | El Sol de México
# 📰 El patrón virtual y el futuro de la seguridad social en México - El Sol de México | 2026-02-02 | El Sol de México
# 📰 Locatarios de Tulancingo exigen más seguridad ante robos - El Sol de México | 2026-02-03 | El Sol de México
# 📰 Noem anuncia que todos los agentes de Seguridad Interior en Minneapolis usarán cámaras corporales - Proceso | 2026-02-03 | Proceso
# 📰 Mundial de Futbol en México: el reto de la ciberseguridad y la protección de datos personales - Proceso | 2026-02-01 | Proceso
# 📰 Las monedas de 10 pesos cambiarán de aleación para reforzar su seguridad - SDPnoticias.com | 2026-02-02 | SDPnoticias.com
# 📰 Capacitación, promoción y seguridad, así se prepara hoteleros de Hidalgo rumbo al Mundial - La Silla Rota | 2026-02-03 | La Silla Rota
# 📰 Tulancingo se quedó sin clínica de especialidades por baja seguridad social, revela alcaldesa - La Silla Rota | 2026-02-02 | La Silla Rota
# 📰 Puebla: alerta por inseguridad en ciclopista de San Andrés Cholula - La Silla Rota | 2026-02-02 | La Silla Rota
# 📰 Peludos alivian salud emocional en el AIFA; aportan seguridad y calma en la terminal - Excélsior | 2026-02-02 | Excélsior
# 📰 El impuesto invisible de la inseguridad en la economía formal - Excélsior | 2026-02-02 | Excélsior
# 📰 Guardia de seguridad asalta la tienda que le toca vigilar - Excélsior | 2026-02-02 | Excélsior
# 📰 Regreso a clases con nueva seguridad en el CCH Sur: Todo lo que cambió tras la tragedia - MVS Noticias | 2026-02-02 | MVS Noticias
# 📰 Waldo Fernández promete poner seguridad y bienestar de Nuevo León en el centro de la agenda nacional - MVS Noticias | 2026-02-02 | MVS Noticias
# 📰 Caen tres por robo en supermercado del Centro de Monterrey; uno era guardia de seguridad - MVS Noticias | 2026-02-02 | MVS Noticias
# 📰 Revisa Cuautitlán Izcalli mecanismos de seguridad en plazas comerciales y tiendas departamentales - La Jornada | 2026-02-03 | La Jornada
# 📰 Empresarios piden ampliar plazo para generar Dictamen de Seguridad Estructural, tras sismo de enero - La Jornada | 2026-02-02 | La Jornada
# 📰 La UNAM planea unificar protocolos de seguridad en sus 14 planteles de bachillerato - La Jornada | 2026-02-02 | La Jornada
# 📰 TAG - dictamenes de seguridad estructural - La Jornada | 2026-02-02 | La Jornada
# 📰 Departamento de Seguridad de EU ordena el cierre de instalaciones de ICE en Texas por brote de sarampión - La Jornada | 2026-02-02 | La Jornada
# 📰 Israel reabre el cruce de Rafah bajo estrictas medidas de seguridad y control militar - La Jornada | 2026-02-02 | La Jornada
