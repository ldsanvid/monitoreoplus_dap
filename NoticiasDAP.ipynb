# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta, timezone
from urllib.parse import urlparse
from dateutil import parser
import unicodedata
import numpy as np
import os

# === CONFIGURACIÓN GENERAL ===

# 1) Términos ligados a intereses de clientes DAP
terminos_busqueda = [
    "industria alimentaria",
    "cemento",
    "gas",
    "impuesto", 
    "iva",
    "casinos",
    "movilidad",
    "seguridad",
]

# 2) Búsqueda general para agenda nacional
termino_agenda_nacional = ["Sheinbaum","aranceles","trump"]

# Modo de fecha
modo = "rango"  # Opciones: "exacto" o "rango"
debug = True    # True para imprimir detalles por noticia
dias_rango = 1  # Solo si modo == "rango"
fecha_objetivo = datetime(2025, 11, 2).date()  # Solo si modo == "exacto"

# Lista de medios (de momento vacía: tú la llenas con tus sitios)
medios = ["eleconomista.com.mx","imagenradio.com.mx","elfinanciero.com.mx","forbes.com.mx","merca20.com",
    "eluniversal.com.mx","heraldodemexico.com.mx/nacional","nexos.com.mx","thelogisticsworld.com","t21.com.mx",
    "articulo19.org","animalpolitico.com","sinembargo.mx","codigomagenta.com.mx","latinus.us","expansion.mx",
    "nmas.com.mx/nacional","radioformula.com.mx","wradio.com.mx","unotv.com","tvazteca.com/aztecanoticias","infobae.com/mexico",
    "la-lista.com/mexico","oem.com.mx/la-prensa","oem.com.mx/elsoldemexico","proceso.com.mx","vertigopolitico.com","sdpnoticias.com",
    "lasillarota.com/nacion","excelsior.com.mx","letraslibres.com","elpais.com/mexico/","mvsnoticias.com","latimes.com","jornada.com.mx",
    "cnnespanol.cnn.com/","nytimes.com","mexico.quadratin.com.mx","milenio.com","informador.mx","washingtonpost.com",
    "realestatemarket.com.mx/mercado-inmobiliario-home/industrial","alfamexico.com/category/noticias-inmobiliarias/",
    "inmobiliare.com/","jll.com.mx/es/newsroom","eleconomista.com.mx/tags/sector-inmobiliario","milenio.com/temas/sector-inmobiliario",
    "somosindustria.com/", "mexicoindustry.com/","thelogisticsworld.com/","bloomberglinea.com/latinoamerica/mexico/"
]

headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/109.0.0.0 Safari/537.36"
    )
}

# === FUNCIONES AUXILIARES ===

def normalizar(texto):
    if not isinstance(texto, str):
        return ""
    texto = texto.lower().strip()
    texto = unicodedata.normalize("NFKD", texto)
    texto = "".join([c for c in texto if not unicodedata.combining(c)])
    return texto

def parsear_fecha_pub(pub_date_str):
    """
    Intenta parsear la fecha del feed RSS de Google News.
    Devuelve objeto datetime con timezone.
    """
    try:
        dt = parser.parse(pub_date_str)
        if dt.tzinfo is None:
            dt = dt.replace(tzinfo=timezone.utc)
        return dt
    except Exception:
        return None

# === SCRAPING DE NOTICIAS POR TÉRMINO Y MEDIO ===

noticias = []
ahora = datetime.now(timezone.utc)

for termino in terminos_busqueda:
    print(f"\n🔍 Buscando: {termino}")

    for medio in medios:
        dominio = urlparse("https://" + medio).netloc
        # Configuración para México
        url = (
            f"https://news.google.com/rss/search?"
            f"q={termino}+site:{dominio}"
            f"&hl=es-419&gl=MX&ceid=MX:es"
        )

        response = requests.get(url, headers=headers)
        if response.status_code != 200:
            print(f"⚠️ Error al obtener noticias de {dominio}")
            continue

        soup = BeautifulSoup(response.content, "xml")
        items = soup.find_all("item")

        for item in items:
            title = item.title.text if item.title else ""
            link = item.link.text if item.link else ""
            pub_date_str = item.pubDate.text if item.pubDate else ""

            pub_date = parsear_fecha_pub(pub_date_str)
            if pub_date is None:
                continue

            # Filtrado por fecha
            if modo == "exacto":
                if pub_date.date() != fecha_objetivo:
                    continue
            elif modo == "rango":
                if ahora - pub_date > timedelta(days=dias_rango):
                    continue

                source = item.source.text if item.source else ""
                description = item.description.text if item.description else ""
                contenido = f"{title} {description}".lower()
                if termino.lower() in contenido:
                    if debug:
                        print(f"📰 {title} | {pub_date.date()} | {source}")
                    noticias.append([
                        pub_date.astimezone(timezone.utc),
                        title,
                        link,
                        termino,
                        source,  # aquí guardamos el medio
                    ])


# === BLOQUE EXTRA: TITULARES GENERALES PARA "AGENDA NACIONAL" ===

from urllib.parse import quote_plus  # ya lo tienes arriba, pero no pasa nada si está repetido

print("\n🔍 Buscando titulares generales de México (agenda_nacional)")

# Construimos una query OR con las palabras de agenda nacional
# Ejemplo: "Sheinbaum OR aranceles OR trump"
query_agenda = " OR ".join(termino_agenda_nacional)
query_agenda_encoded = quote_plus(query_agenda)

url_agenda = (
    "https://news.google.com/rss/search?"
    f"q={query_agenda_encoded}"
    "&hl=es-419&gl=MX&ceid=MX:es"
)

response = requests.get(url_agenda, headers=headers)
if response.status_code == 200:
    soup = BeautifulSoup(response.content, "xml")
    items = soup.find_all("item")

    # Tomamos solo 4–5 ítems (ajustable)
    max_agenda = 15
    count = 0

    for item in items:
        if count >= max_agenda:
            break

        title = item.title.text if item.title else ""
        link = item.link.text if item.link else ""
        pub_date_str = item.pubDate.text if item.pubDate else ""
        pub_date = parsear_fecha_pub(pub_date_str)
        if pub_date is None:
            continue

        # Mismo filtro de fecha que en el resto del scraper
        if modo == "exacto":
            if pub_date.date() != fecha_objetivo:
                continue
        elif modo == "rango":
            if ahora - pub_date > timedelta(days=dias_rango):
                continue

        if debug:
            print(f"📰 [AGENDA] {title} | {pub_date.date()}")

        # El campo 'medio' lo dejamos vacío; luego se llenará con el split " - "
        noticias.append([
            pub_date.astimezone(timezone.utc),
            title,
            link,
            "agenda_nacional",
            ""
        ])
        count += 1
else:
    print("⚠️ No se pudieron obtener titulares generales de México")


# === GUARDAR RESULTADOS EN CSV NOTICIAS_DAP ===

carpeta_salida = "."  # raíz del proyecto; cambia si quieres "noticias"
os.makedirs(carpeta_salida, exist_ok=True)

if noticias:
    df = pd.DataFrame(
        noticias,
        columns=["fecha_dt", "titular_raw", "enlace", "termino", "medio"]
    )
    # Separar "titulo - Medio"
    partes = df["titular_raw"].str.split(" - ", n=1, expand=True)
    
    # Título limpio (antes del " - ")
    df["titular"] = partes[0]
    
    # Medio de comunicación (después del " - ")
    df["medio"] = partes[1].fillna("")

    # Convertir a fecha (sin hora) y a string YYYY-MM-DD
    df["fecha_dt"] = pd.to_datetime(df["fecha_dt"], errors="coerce")
    df = df[df["fecha_dt"].notna()]
    df["fecha"] = df["fecha_dt"].dt.strftime("%Y-%m-%d")
    # Nos quedamos solo con las columnas que quieres
    df_final = df[["fecha", "titular", "termino", "enlace", "medio"]].drop_duplicates()

    # Nombre del archivo
    sufijo_fecha = (
        fecha_objetivo.strftime("%Y-%m-%d")
        if modo == "exacto"
        else ahora.strftime("%Y-%m-%d")
    )
    nombre_archivo = os.path.join(
        carpeta_salida,
        f"noticias_dap_{sufijo_fecha}.csv"
    )

    df_final.to_csv(nombre_archivo, index=False, encoding="utf-8-sig")
    print(f"\n✅ Archivo guardado como '{nombre_archivo}' con {len(df_final)} noticias")
else:
    print("\n❌ No se encontraron noticias que cumplan los filtros.")
# Out:
# 🔍 Buscando: industria alimentaria
#
# 🔍 Buscando: cemento
#
# 🔍 Buscando: gas
# 📰 Mueren dos funcionarios de Protección Civil de Naucalpan por presunta fuga de gas en su vivienda - El Universal | 2026-01-31 | El Universal
# 📰 Explosión en ciudad iraní del Golfo fue causada por escape de gas, según los bomberos y medios descartan posible ataque o sabotaje - El Universal | 2026-01-31 | El Universal
# 📰 Trabajos de repavimentación provocan fuga de gas en avenida Hank González, en Coacalco - El Universal | 2026-01-31 | El Universal
# 📰 Muere subdirector de Protección Civil y su esposa en Naucalpan por intoxicación de gas, investigan posible homicidio - El Heraldo de México | 2026-01-31 | El Heraldo de México
# 📰 Las gasolineras de México viven un año clave ante su regulación y tienen un gran problema: el huachicol - expansion.mx | 2026-01-31 | expansion.mx
# 📰 Muere Mujer Tras Explosión por Acumulación de Gas en Guadalupe, Nuevo León - N+ | 2026-01-31 | N+
# 📰 Protección Civil de Coacalco Confirma que Fuga de Gas ya Fue Controlada - N+ | 2026-01-31 | N+
# 📰 Fuga de Gas en Coacalco: Desalojan Familias Tras Perforación de Ducto Subterráneo - N+ | 2026-01-31 | N+
# 📰 ¡El mejor momento para llenar el tanque! Así quedó el precio de la gasolina para este sábado 31 de enero 2026 - TV Azteca | 2026-01-31 | TV Azteca
# 📰 El régimen iraní informó que la explosión ocurrida en un edificio de Bandar Abbas fue “por una fuga de gas” - Infobae | 2026-01-31 | Infobae
# 📰 Explosión de balón de gas en taller mécanico sacude Chiclayo: hombre muere decapitado y mujer queda gravemente herida - Infobae | 2026-01-31 | Infobae
# 📰 El déficit comercial de España con Estados Unidos se dispara casi un 50% por el aumento de las importaciones de gas - Infobae | 2026-01-31 | Infobae
# 📰 Trabajos de repavimentación provocan fuga de gas natural en Coacalco - El Sol de México | 2026-02-01 | El Sol de México
# 📰 Trabajos de repavimentación provocan fuga de gas natural en Coacalco - El Sol de México | 2026-02-01 | El Sol de México
# 📰 PC de Coacalco controla fuga de gas tras perforación accidental de tubo; desalojan 60 familias - La Jornada | 2026-01-31 | La Jornada
# 📰 Mueren subdirector de Protección Civil de Naucalpan y su esposa por presunta inhalación de gas - La Jornada | 2026-01-31 | La Jornada
# 📰 Estos serán los precios del gas LP del 1 al 7 de febrero en Puebla - MILENIO | 2026-01-31 | MILENIO
# 📰 ¿Más caro? Aquí los precios del gas LP en Jalisco del 1 al 7 de febrero - MILENIO | 2026-01-31 | MILENIO
# 📰 Muere adulta mayor tras explosión por acumulación de gas dentro de casa en Guadalupe - MILENIO | 2026-01-31 | MILENIO
# 📰 Estos serán los precios del gas LP del 1 al 7 de febrero en Puebla - MILENIO | 2026-01-31 | MILENIO
# 📰 ¿Más caro? Aquí los precios del gas LP en Jalisco del 1 al 7 de febrero - MILENIO | 2026-01-31 | MILENIO
# 📰 Muere adulta mayor tras explosión por acumulación de gas dentro de casa en Guadalupe - MILENIO | 2026-01-31 | MILENIO
#
# 🔍 Buscando: impuesto
# 📰 ¿Cómo tramitar el cambio de placas a Edomex para obtener el subsidio del 100% en impuestos vehiculares? | PASO A PASO - El Heraldo de México | 2026-01-31 | El Heraldo de México
# 📰 La actividad industrial de China cayó en enero por falta de demanda y complica al modelo impuesto por Xi Jinping - Infobae | 2026-01-31 | Infobae
# 📰 La Gobernadora del Valle advierte impacto social por impuesto al licor: “Los megaricos no toman aguardiente” - Infobae | 2026-01-31 | Infobae
# 📰 Sunat te puede devolver hasta S/ 4.950 del impuesto a la renta en tu cuenta: Así funciona - Infobae | 2026-01-31 | Infobae
# 📰 Sunat: Estos son los gastos que podrás deducir de tu impuesto a la renta por S/ 16.500 en 2026 - Infobae | 2026-01-31 | Infobae
#
# 🔍 Buscando: iva
# 📰 Activan rescate de montaña por persona lesionada en La Huasteca, Santa Catarina - MVS Noticias | 2026-01-31 | MVS Noticias
#
# 🔍 Buscando: casinos
#
# 🔍 Buscando: movilidad
# 📰 Los países bálticos aprueban un área de movilidad militar para facilitar el paso transfronterizo de sus ejércitos - Infobae | 2026-01-31 | Infobae
# 📰 La electromovilidad despega; la red de carga sigue en tierra - MILENIO | 2026-01-31 | MILENIO
# 📰 La electromovilidad despega; la red de carga sigue en tierra - MILENIO | 2026-01-31 | MILENIO
#
# 🔍 Buscando: seguridad
# 📰 Migración, comercio y seguridad: el eje de las llamadas entre Sheinbaum y Trump - El Economista | 2026-02-01 | El Economista
# 📰 Anuncia Gobernador de NL colaboración RapidSOS para reforzar la seguridad rumbo al Mundial - Imagen Radio 90.5 | 2026-01-31 | Imagen Radio 90.5
# 📰 El miedo en el trabajo es un riesgo de seguridad oculto y ayuda a explicar por qué los peligros no se denuncian - Forbes México | 2026-01-31 | Forbes México
# 📰 Marina capacita a 34 elementos para detectar amenazas químicas durante el Mundial 2026; buscan mayor seguridad - El Universal | 2026-01-31 | El Universal
# 📰 Embajada de EU en Haití emite alerta de seguridad por "intensos tiroteos" en Puerto Príncipe - El Universal | 2026-01-31 | El Universal
# 📰 Refuerzan seguridad y controles en frontera de Chiapas ante el estado de sitio de Guatemala - LatinUS | 2026-01-31 | LatinUS
# 📰 C4 Norte de Monterrey toma forma: obra alcanza 31% y promete reforzar la seguridad - Radio Fórmula | 2026-01-31 | Radio Fórmula
# 📰 El infinito problema de seguridad para niños en Roblox: lo que deben saber los padres - UnoTV | 2026-01-31 | UnoTV
# 📰 Llamada Marco Rubio–Juan Ramón de la Fuente por seguridad regional - UnoTV | 2026-01-31 | UnoTV
# 📰 Violación en Miramar: intensa búsqueda del sospechoso y las cámaras de seguridad clave que analiza la Justicia - Infobae | 2026-01-31 | Infobae
# 📰 El régimen de Irán volvió a desafiar a EEUU: “Si comete un error, pondrá en riesgo su propia seguridad” - Infobae | 2026-01-31 | Infobae
# 📰 Jefe de seguridad de Hidrandina desató balacera y se quitó la vida tras ser despedido: reportan tres heridos - Infobae | 2026-01-31 | Infobae
# 📰 "La guerra en Ucrania sigue siendo la mayor amenaza mundial para la seguridad nuclear", advierte el OIEA - Infobae | 2026-01-31 | Infobae
# 📰 Federico Gutiérrez denunció que grupos delincuenciales de Medellín prestan seguridad y logística a capos de bandas criminales a nivel internacional - Infobae | 2026-01-31 | Infobae
# 📰 Hablan Rubio y De la Fuente sobre prioridades compartidas y seguridad regional - El Sol de México | 2026-01-31 | El Sol de México
# 📰 Piden más seguridad durante la búsqueda de personas desaparecidas en SLP - El Sol de México | 2026-01-31 | El Sol de México
# 📰 Red global de seguridad de cables submarinos - El Sol de México | 2026-01-31 | El Sol de México
# 📰 Secretaría de Seguridad Pública de Pachuca despliega operativo Águila - El Sol de México | 2026-01-31 | El Sol de México
# 📰 Universidad de la Academia Metropolitana de Seguridad: 188 elementos se profesionalizan en Derecho y Ciberseguridad - El Sol de México | 2026-01-31 | El Sol de México
# 📰 Congreso del Edomex fija como prioridad transparencia, seguridad y reforma electoral - El Sol de México | 2026-02-01 | El Sol de México
# 📰 Hablan Rubio y De la Fuente sobre prioridades compartidas y seguridad regional - El Sol de México | 2026-01-31 | El Sol de México
# 📰 Piden más seguridad durante la búsqueda de personas desaparecidas en SLP - El Sol de México | 2026-01-31 | El Sol de México
# 📰 Red global de seguridad de cables submarinos - El Sol de México | 2026-01-31 | El Sol de México
# 📰 Secretaría de Seguridad Pública de Pachuca despliega operativo Águila - El Sol de México | 2026-01-31 | El Sol de México
# 📰 Universidad de la Academia Metropolitana de Seguridad: 188 elementos se profesionalizan en Derecho y Ciberseguridad - El Sol de México | 2026-01-31 | El Sol de México
# 📰 Congreso del Edomex fija como prioridad transparencia, seguridad y reforma electoral - El Sol de México | 2026-02-01 | El Sol de México
# 📰 Marco Rubio y Juan Ramón de la Fuente hablan sobre agenda en común y seguridad regional - Proceso | 2026-01-31 | Proceso
# 📰 Julia Abarca: “Los empleados valoran cada vez más contar con herramientas que les aporten seguridad y reduzcan la incertidumbre” - EL PAÍS | 2026-01-31 | EL PAÍS
# 📰 Nuevo León integra RapidSOS a su C5 para reforzar la seguridad rumbo al Mundial 2026 - MVS Noticias | 2026-01-31 | MVS Noticias
# 📰 Aprueba Senado de EU financiamiento del gobierno y prórroga temporal para Seguridad Nacional - La Jornada | 2026-01-31 | La Jornada
# 📰 La inseguridad que no cabe en una mañanera - MILENIO | 2026-01-31 | MILENIO
# 📰 Nuevo León colabora con RapidSOS para seguridad del Mundial - MILENIO | 2026-01-31 | MILENIO
# 📰 Operativo de seguridad Cancún desarticulan grupo criminal Sinaloa - MILENIO | 2026-01-31 | MILENIO
# 📰 Serie del Caribe 2026: Alistan operativo de seguridad en Zapopan - El Informador | 2026-01-31 | El Informador
# 📰 Seguridad en Jalisco: Policía de Guadalajara detiene a diez personas por portación de armas en cuatro colonias distintas - El Informador | 2026-01-31 | El Informador
# 📰 México refuerza seguridad y controles en la frontera ante estado de sitio en Guatemala - El Informador | 2026-01-31 | El Informador
# 📰 Migración, comercio y seguridad: el eje de las llamadas entre Sheinbaum y Trump - El Economista | 2026-02-01 | El Economista
# 📰 La inseguridad que no cabe en una mañanera - MILENIO | 2026-01-31 | MILENIO
# 📰 Nuevo León colabora con RapidSOS para seguridad del Mundial - MILENIO | 2026-01-31 | MILENIO
# 📰 Operativo de seguridad Cancún desarticulan grupo criminal Sinaloa - MILENIO | 2026-01-31 | MILENIO
#
# 🔍 Buscando titulares generales de México (agenda_nacional)
# 📰 [AGENDA] Sheinbaum alerta de que los aranceles de Trump pueden crear una "crisis humanitaria de gran alcance" en Cuba - Diario Red | 2026-01-31
# 📰 [AGENDA] Claudia Sheinbaum Pardo - facebook.com | 2026-01-31
# 📰 [AGENDA] Boxeador Ryan García dice que retira su apoyo a Donald Trump - Los Angeles Times | 2026-01-31
# 📰 [AGENDA] Trump aparece al menos 3 mil veces en el último lote de los archivos Epstein - La Jornada | 2026-01-31
# 📰 [AGENDA] Sheinbaum inaugurará carretera Bavispe – Nuevo Casas Grandes - IMER Noticias | 2026-01-31
# 📰 [AGENDA] ¿Qué revelan 3 millones de nuevos documentos sobre los vínculos de Trump con Jeffrey Epstein? - CNN en Español | 2026-01-31
# 📰 [AGENDA] Sheinbaum formaliza Plan de Justicia para trabajadores agrícolas de San Quintín - masnoticias.mx | 2026-01-31
# 📰 [AGENDA] Trump afirma que Irán "está hablando" con Estados Unidos - dw.com | 2026-01-31
# 📰 [AGENDA] Archivos Epstein: testigo del Cártel de Sinaloa vincula a Trump con fiestas sexuales en su campo de golf - LatinUS | 2026-01-31
# 📰 [AGENDA] Migración, comercio y seguridad: el eje de las llamadas entre Sheinbaum y Trump - El Economista | 2026-02-01
# 📰 [AGENDA] Resumen de ‘Melania’, el documental sobre la primera dama de Estados Unidos - The New York Times | 2026-01-31
# 📰 [AGENDA] Trump aplicará aranceles a países que vendan petróleo a Cuba - dw.com | 2026-01-31
# 📰 [AGENDA] Trump ordena a agentes federales mantenerse al margen de protestas por migración - La Jornada | 2026-01-31
# 📰 [AGENDA] Trump dice que Irán "está hablando" con EU ante amenaza de ataques militares - La Jornada | 2026-01-31
# 📰 [AGENDA] 5 revelaciones de los millones de archivos Epstein que acaban de salir a la luz - BBC | 2026-01-31
#
# ✅ Archivo guardado como '.\noticias_dap_2026-02-01.csv' con 71 noticias
